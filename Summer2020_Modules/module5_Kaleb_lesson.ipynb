# %% [markdown]
# # Image Processing Module 5: The Power of Thresholds

# %% [markdown]
# ### Purpose: Introduce the concepts of thresholds within image processing

# %% [markdown]
# *Step 1: Necessary Imports*

# %%
import numpy as np
from skimage import io
import matplotlib.pyplot as plt

# %% [markdown]
# *Step 2: User Input*

# %%
cell_im_location = r'C:\Users\Kaleb\Documents\GitHub\textile\example_data\ogd_cells.tif'

# %% [markdown]
# *Step 3: Read in the image*

# %%
cell_im = io.imread(cell_im_location)

# %% [markdown]
# *Step 4: View the Image*

# %%
plt.imshow(cell_im)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# *Step 5: Splitting our channels for Thresholding*

# %%
red_cell_im = cell_im[:,:,0]
green_cell_im = cell_im[:,:,1]
blue_cell_im = cell_im[:,:,2]

# %%
green_cell_im
# Out:
# array([[ 25, 101,  65, ...,  16,  11,   0],
#        [122, 136,  74, ...,  14,   8,  11],
#        [ 29,  84, 111, ...,  22,   0,  15],
#        ...,
#        [ 22, 140,  78, ...,  11,   7,   0],
#        [ 80,  59, 102, ...,   8,  11,  15],
#        [ 27,  52,  27, ...,   0,   1,   0]], dtype=uint16)

# %%
plt.imshow(green_cell_im, cmap = 'gray', vmin = 0, vmax = 255)

# %%
green_cell_im
# Out:
# array([[ 25, 101,  65, ...,  16,  11,   0],
#        [122, 136,  74, ...,  14,   8,  11],
#        [ 29,  84, 111, ...,  22,   0,  15],
#        ...,
#        [ 22, 140,  78, ...,  11,   7,   0],
#        [ 80,  59, 102, ...,   8,  11,  15],
#        [ 27,  52,  27, ...,   0,   1,   0]], dtype=uint16)
